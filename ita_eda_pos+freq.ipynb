# %% [markdown]
# <a href="https://colab.research.google.com/github/dilakuyucu7/DSA210-Fall24-Flashcards-Project/blob/main/ita_eda_pos%2Bfreq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = '/content/ita_progress_with_pos_stanza.csv'  # Adjust this path to your file location
df = pd.read_csv(file_path)

# Ensure columns match the file structure
df.columns = ['Word', 'Card was added', 'Studied', 'Correct answers', 'Incorrect answers', 'Part of Speech']

# Drop any rows with missing values in important columns
df.dropna(subset=['Word', 'Part of Speech'], inplace=True)

# 1. Count and percentage of words per part of speech
pos_counts = df['Part of Speech'].value_counts()
pos_percentages = (pos_counts / pos_counts.sum()) * 100

print("Words per Part of Speech:")
print(pos_counts)
print("\nPercentage of Words per Part of Speech:")
print(pos_percentages)

# Plotting Part of Speech Distribution
plt.figure(figsize=(10, 6))
pos_counts.plot(kind='bar', color='red')
plt.title('Part of Speech Distribution')
plt.xlabel('Part of Speech')
plt.ylabel('Word Count')
plt.xticks(rotation=45)
plt.show()

# 2. Frequency distribution of word lengths
df['Word Length'] = df['Word'].apply(len)
word_length_counts = df['Word Length'].value_counts().sort_index()

print("\nFrequency Distribution of Word Lengths:")
print(word_length_counts)

# Plotting Word Length Distribution
plt.figure(figsize=(10, 6))
word_length_counts.plot(kind='bar', color='red')
plt.title('Frequency Distribution of Word Lengths')
plt.xlabel('Word Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# Words per Part of Speech:
# Part of Speech
# NOUN     553
# VERB     487
# ADJ      145
# ADV      115
# DET       71
# ADP       49
# PRON      32
# CCONJ      8
# AUX        6
# INTJ       5
# PROPN      3
# NUM        2
# PUNCT      2
# SCONJ      1
# X          1
# Name: count, dtype: int64
#
# Percentage of Words per Part of Speech:
# Part of Speech
# NOUN     37.364865
# VERB     32.905405
# ADJ       9.797297
# ADV       7.770270
# DET       4.797297
# ADP       3.310811
# PRON      2.162162
# CCONJ     0.540541
# AUX       0.405405
# INTJ      0.337838
# PROPN     0.202703
# NUM       0.135135
# PUNCT     0.135135
# SCONJ     0.067568
# X         0.067568
# Name: count, dtype: float64
# Frequency Distribution of Word Lengths:
# Word Length
# 2       6
# 3      21
# 4      91
# 5     203
# 6     227
# 7     235
# 8     198
# 9     162
# 10    133
# 11     68
# 12     36
# 13     25
# 14     18
# 15     12
# 16     14
# 17     10
# 18      5
# 19      6
# 20      4
# 21      2
# 22      2
# 23      1
# 24      1
# Name: count, dtype: int64
